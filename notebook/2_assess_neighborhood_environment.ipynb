# %% [markdown]
# # **Workshop: Capturing Human Perception of Neighborhoods Using Online Data with Language and Vision Models**
#
# # **Train a new coder, Stella using StreetLens**
#
# In this session, we will explore how StreetLens helps automate neighborhood environment assessments.
#
# StreetLens is a researcher-focused workflow that combines your domain expertise with vision-language models and street view imagery to generate meaningful, scalable annotations—no heavy coding required.
#
# Curious how to scale expert-level evaluation across neighborhoods? Let's get started.
#
# **Note:** The datasets provided are for demo purposes only and should not be shared outside this environment.

# %% [markdown]
# ## Before we start:
# Make sure to save a copy of this Jupyter notebook to your own Google Drive,
# so that you can make edits and run the code yourself.
#
# Go to a tab **File → Save a copy in Drive**, then run the code in your copy.
#
# <img src = "https://drive.google.com/uc?id=1RtVrYCxlT-nsNNrBWvuzfwfHgZkaXnzV" height = 400 width = 650>

# %% [markdown]
# 1. Connect to the shared Google Drive where the data and StreetLens files are stored

# %%
from google.colab import drive
drive.mount('/content/Shareddrives')
# Out:
# Mounted at /content/Shareddrives

# %%
# %cd /content/Shareddrives/Shareddrives/UCGIS2025-Workshop-CSENG-Computer\ Science
# Out:
# /content/Shareddrives/Shareddrives/UCGIS2025-Workshop-CSENG-Computer Science

# %% [markdown]
# 2. Install the required packages for StreetLens

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (4.52.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers->-r requirements.txt (line 1)) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers->-r requirements.txt (line 1)) (0.33.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers->-r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers->-r requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers->-r requirements.txt (line 1)) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers->-r requirements.txt (line 1)) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers->-r requirements.txt (line 1)) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers->-r requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers->-r requirements.txt (line 1)) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers->-r requirements.txt (line 1)) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers->-r requirements.txt (line 1)) (1.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->-r requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->-r requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->-r requirements.txt (line 1)) (2025.6.15)

# %% [markdown]
# 3. Load the case study data previously prepared for StreetLens.

# %%
from streetlens.data_processor import *
from streetlens.automated_prompt_tuner import *
from streetlens.vision_language_model_processor import *

codebook_path = './dataset/annotation/sso_codebook.json'
paper_path = './dataset/paper/abstract.json'
annotation_path = './dataset/annotation/sso_annotation.csv'
street_block_id = ['281']
# street_block_id = ['62146', '281', '282', '9576']
agent_annotation_path = './dataset/annotation/agent_annotation.csv'

data_config = DataProcessor.DataConfig(codebook_path=codebook_path, annotation_path=annotation_path, paper_path=paper_path, street_block_id=street_block_id)
data_processor = DataProcessor(data_config=data_config)

data_config.image_dir = './dataset/img/'
data_config.agent_annotation_path = agent_annotation_path

# %% [markdown]
# 4. Let’s configure the lightweight vision-language model that StreetLens will use

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
data_config.model_name = 'OpenGVLab/InternVL3-2B-hf'
vlm_processor = VLMProcessor(data_processor.data_config, device=device)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.96k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/4.18G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/126 [00:00<?, ?B/s]
# processor_config.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/481 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/6.86k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/811 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/877 [00:00<?, ?B/s]
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.

# %% [markdown]
# 5. Let’s enable AutomatedPromptTuner to assign a role to Stella and refine the codebook questions.

# %%
automated_prompt_tuner = AutomatedPromptTuner(data_config=data_config, vlm_processor=vlm_processor)

# %%
# role prompt
role_prompt = automated_prompt_tuner.construct_role_prompt()
# Out:
# Stella: Looks like we have 2 abstract(s). Let me step into a new role. I’m ready for it!
# Stella: I am an expert in mixed methods research and qualitative analysis, with a specific focus on comparing researchers' and adolescents' observations of neighborhood environments. My expertise includes exploring the shared and unique aspects of these observations and examining ethnic-racial label usage in the context of segregated neighborhoods. I have conducted studies that highlight these aspects and have contributed to the understanding of how different perspectives on neighborhood environments

# %%
# codebook prompt
codebook_prompt = automated_prompt_tuner.construct_codebook_prompt()
# Out:
# Stella: I'm reading codebook...
# Stella: I'm looking over the question-answer pairs for measure Disorder 3. I'm refining the codebook prompt...
# Stella: I'm looking over the question-answer pairs for measure Decay 1. I'm refining the codebook prompt...
# Stella: I'm looking over the question-answer pairs for measure Decay 2. I'm refining the codebook prompt...
# Stella: I'm looking over the question-answer pairs for measure SS4. I'm refining the codebook prompt...
# Stella: I'm looking over the question-answer pairs for measure SS5. I'm refining the codebook prompt...

# %% [markdown]
# 6. For each measure, Stella will review and annotate each image. Then StreetLens will generate an aggregated annotation file at the same level as the sample annotations made by human coders (e.g., 1 annotation per street block).

# %%
data_config.role_prompt = automated_prompt_tuner.role_prompt
data_config.codebook_prompt_dict = automated_prompt_tuner.codebook_prompt_dict
vlm_processor.generate_annotation()
# Out:
# Stella: Jumping into measure Disorder 3...
#
# 	Stella: I got the image from ./dataset/img/281/W/6.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: The image does not show any visible graffiti on buildings, signs, walls, fences, sidewalks, poles, or streets. The scene appears to be a quiet residential area with no signs of graffiti.
#
# 	Stella: I got the image from ./dataset/img/281/W/8.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: The image does not show any visible graffiti on buildings, signs, walls, fences, sidewalks, poles, or streets. The scene appears to be a quiet street with a car and some trees, but no graffiti is present. The focus is on the car and the surrounding environment, which does not include any markings or tags.
#
# 	Stella: I got the image from ./dataset/img/281/W/10.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: The image does not show any visible graffiti on buildings, signs, walls, fences, sidewalks, poles, or streets. The scene appears to be a quiet street with no signs of graffiti.
#
# 	Stella: I got the image from ./dataset/img/281/W/1.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: The image does not show any visible graffiti on buildings, signs, walls, fences, sidewalks, poles, or streets. The scene appears to be a quiet, possibly residential area with no signs of graffiti.
#
# 	Stella: I got the image from ./dataset/img/281/W/3.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: The image does not show any visible graffiti on buildings, signs, walls, fences, sidewalks, poles, or streets. The scene appears to be a quiet residential area with no signs of graffiti.
#
# 	Stella: I got the image from ./dataset/img/281/W/2.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: The image does not show any visible graffiti on buildings, signs, walls, fences, sidewalks, poles, or streets. The scene appears to be a quiet residential area with no signs of graffiti.
#
# 	Stella: I got the image from ./dataset/img/281/W/5.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: The image shows a street view with no visible graffiti on buildings, signs, walls, fences, sidewalks, poles, or streets. The area appears clean and well-maintained, with only a few bare trees and a residential house in the background. There are no markings, tags, or spray paint present in the image.
#
# 	Stella: I got the image from ./dataset/img/281/W/7.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: The image shows a gas station with no visible graffiti on buildings, signs, walls, fences, sidewalks, poles, or streets. The area appears clean and well-maintained.
#
# 	Stella: I got the image from ./dataset/img/281/W/9.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: The image shows a gas station with no visible graffiti on buildings, signs, walls, fences, sidewalks, poles, or streets. The area appears clean and well-maintained.
#
# Stella: Jumping into measure Decay 1...
#
# 	Stella: I got the image from ./dataset/img/281/W/6.jpg. I'm starting annotation now...
# 	Stella: My annotation is 3
# 	Stella: The street shows significant cracks and potholes, indicating poor condition. Most of the street has noticeable damage, with cracks and potholes that have not been recently filled in. This suggests the street is in a poor condition.
#
# 	Stella: I got the image from ./dataset/img/281/W/8.jpg. I'm starting annotation now...
# 	Stella: My annotation is 3
# 	Stella: The street shows significant cracks and potholes, indicating poor condition. Most of the street has noticeable damage, with minimal recent filling. This suggests the street is in a poor condition.
#
# 	Stella: I got the image from ./dataset/img/281/W/10.jpg. I'm starting annotation now...
# 	Stella: My annotation is 3
# 	Stella: The street shows significant cracks and potholes, indicating poor condition. Most of the street has noticeable damage, with cracks and potholes that have not been recently filled in. This suggests the street is in a poor condition.
#
# 	Stella: I got the image from ./dataset/img/281/W/1.jpg. I'm starting annotation now...
# 	Stella: My annotation is 3
# 	Stella: The street in the image shows significant cracks and potholes, indicating poor condition. Most of the street appears to have substantial damage, with cracks and potholes that have not been recently filled in. This suggests that the street is in a poor condition.
#
# 	Stella: I got the image from ./dataset/img/281/W/3.jpg. I'm starting annotation now...
# 	Stella: My annotation is 3
# 	Stella: The street in the image shows significant cracks and potholes, indicating poor condition. Most of the street appears to have substantial damage, with cracks and potholes that have not been recently filled in. This suggests that the street is in a poor condition.
#
# 	Stella: I got the image from ./dataset/img/281/W/2.jpg. I'm starting annotation now...
# 	Stella: My annotation is 3
# 	Stella: The street shows significant cracks and potholes, indicating poor condition. Most of the street has noticeable damage, with cracks and potholes that have not been recently filled in. This suggests the street is in a poor condition.
#
# 	Stella: I got the image from ./dataset/img/281/W/5.jpg. I'm starting annotation now...
# 	Stella: My annotation is 3
# 	Stella: The street in the image shows significant cracks and potholes, indicating poor condition. Most of the street is affected, with substantial damage that has not been recently repaired. This suggests the street is in a poor condition.
#
# 	Stella: I got the image from ./dataset/img/281/W/7.jpg. I'm starting annotation now...
# 	Stella: My annotation is 3
# 	Stella: The street in the image shows significant cracks and potholes, indicating poor condition. Most of the street appears to be affected, with substantial damage that has not been recently repaired.
#
# 	Stella: I got the image from ./dataset/img/281/W/9.jpg. I'm starting annotation now...
# 	Stella: My annotation is 3
# 	Stella: The street in the image shows significant cracks and potholes, indicating poor condition. Most of the street appears to have substantial damage, with cracks and potholes that have not been recently filled in. This suggests that the street is in a poor condition.
#
# Stella: Jumping into measure Decay 2...
#
# 	Stella: I got the image from ./dataset/img/281/W/6.jpg. I'm starting annotation now...
# 	Stella: My annotation is 3
# 	Stella: The sidewalk in the image shows significant signs of deterioration, including sizable cracks and outgrown weeds along most of the sidewalk. This indicates poor conditions, making it unsuitable for safe walking. The presence of these issues suggests the sidewalk is not in good condition.
#
# 	Stella: I got the image from ./dataset/img/281/W/8.jpg. I'm starting annotation now...
# 	Stella: My annotation is 3
# 	Stella: The sidewalk in the image shows significant signs of wear and tear, with visible holes, sizable cracks, and weeds growing along most of the sidewalk. This indicates poor conditions that are likely to affect pedestrian safety and comfort.
#
# 	Stella: I got the image from ./dataset/img/281/W/10.jpg. I'm starting annotation now...
# 	Stella: My annotation is 3
# 	Stella: The sidewalk in the image shows significant cracks and uneven pavement, with weeds growing along most of the sidewalk. This indicates poor conditions. There are no visible holes or large cracks, but the overall condition is deteriorated. The presence of weeds suggests neglect, which contributes to a poor sidewalk condition.
#
# 	Stella: I got the image from ./dataset/img/281/W/1.jpg. I'm starting annotation now...
# 	Stella: My annotation is 3
# 	Stella: The sidewalk in the image shows significant signs of wear and tear, with visible holes, sizable cracks, and weeds growing along most of the sidewalk. This indicates poor conditions that are likely to affect pedestrian safety and comfort.
#
# 	Stella: I got the image from ./dataset/img/281/W/3.jpg. I'm starting annotation now...
# 	Stella: My annotation is 3
# 	Stella: The sidewalk in the image shows significant signs of wear and tear, with visible holes, sizable cracks, and weeds growing along most of the sidewalk. This indicates poor conditions that are not suitable for safe walking. The presence of these issues suggests the sidewalk is in a poor condition.
#
# 	Stella: I got the image from ./dataset/img/281/W/2.jpg. I'm starting annotation now...
# 	Stella: I got the image from ./dataset/img/281/W/5.jpg. I'm starting annotation now...
# 	Stella: My annotation is 3
# 	Stella: The sidewalk in the image shows significant signs of wear and tear, with visible holes, sizable cracks, and weeds growing along most of the sidewalk. This indicates poor conditions that are likely to affect pedestrian safety and comfort.
#
# 	Stella: I got the image from ./dataset/img/281/W/7.jpg. I'm starting annotation now...
# 	Stella: My annotation is 3
# 	Stella: The sidewalk in the image shows significant cracks, crumbling pavement, and outgrown weeds along most of the sidewalk, indicating poor conditions. There are no visible holes or sizable cracks, and the pavement is not uneven. The presence of weeds suggests neglect, which is characteristic of a poor sidewalk condition.
#
# 	Stella: I got the image from ./dataset/img/281/W/9.jpg. I'm starting annotation now...
# 	Stella: My annotation is 3
# 	Stella: The sidewalk in the image shows significant signs of wear and tear, with visible holes, sizable cracks, and weeds growing along most of the sidewalk. This indicates poor maintenance and a less desirable condition compared to a good or fair sidewalk. The presence of these issues suggests the sidewalk is in a poor condition.
#
# Stella: Jumping into measure SS4...
#
# 	Stella: I got the image from ./dataset/img/281/W/6.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: The image shows a pedestrian crossing sign, indicating the presence of crosswalks or signs signaling to watch for pedestrians. This is a clear indicator of pedestrian safety measures in the neighborhood.
#
# 	Stella: I got the image from ./dataset/img/281/W/8.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: The image shows a pedestrian crossing sign, indicating the presence of crosswalks or signs signaling to watch for pedestrians. This is a clear indicator of pedestrian safety measures in the neighborhood.
#
# 	Stella: I got the image from ./dataset/img/281/W/10.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: The image shows visible crosswalks and pedestrian signs, indicating a focus on safety for pedestrians. These elements are important for both researchers and adolescents in understanding neighborhood environments. The presence of these signs suggests a consideration of pedestrian safety, which is a shared aspect of their observations. However, the image does not provide specific details about the usage of ethnic-racial labels, so this aspect is not as clearly highlighted. Overall, the crosswalks and signs are a notable shared element in the image.
#
# 	Stella: I got the image from ./dataset/img/281/W/1.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: The image shows a street with a crosswalk, indicating the presence of crosswalks or pedestrian signs. However, there are no visible signs specifically signaling to watch for pedestrians. The focus is on the road and surrounding buildings, with no clear indicators of pedestrian safety features.
#
# 	Stella: I got the image from ./dataset/img/281/W/3.jpg. I'm starting annotation now...
# 	Stella: I got the image from ./dataset/img/281/W/2.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: The image shows a street with a visible yellow double line, which typically indicates a no-passing zone, but it does not clearly show crosswalks or pedestrian signs. The road appears to be a two-way street without visible pedestrian markings or signals.
#
# 	Stella: I got the image from ./dataset/img/281/W/5.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: The image shows a street with a double yellow line, which typically indicates a no-passing zone. However, there are no visible crosswalks or pedestrian signs, making it difficult to confirm the presence of crosswalks or signs signaling to watch for pedestrians.
#
# 	Stella: I got the image from ./dataset/img/281/W/7.jpg. I'm starting annotation now...
# 	Stella: I got the image from ./dataset/img/281/W/9.jpg. I'm starting annotation now...
# Stella: Jumping into measure SS5...
#
# 	Stella: I got the image from ./dataset/img/281/W/6.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: There are no visible signs or painted markers indicating designated bike lanes in the image. The road appears to be a standard street without any bike lane markings.
#
# 	Stella: I got the image from ./dataset/img/281/W/8.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: There are no visible signs or painted markers indicating designated bike lanes in the image. The road appears to be a standard street without any bike lane markings.
#
# 	Stella: I got the image from ./dataset/img/281/W/10.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: There are no visible signs or painted markers indicating designated bike lanes in the image. The road appears to be a standard street without any bike lane markings.
#
# 	Stella: I got the image from ./dataset/img/281/W/1.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: There are no visible signs or painted markers indicating designated bike lanes in the image. The road appears to be a standard street without any bike lane markings.
#
# 	Stella: I got the image from ./dataset/img/281/W/3.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: There are no visible signs or painted markers indicating designated bike lanes in the image. The road appears to be a standard street without any bike lane markings.
#
# 	Stella: I got the image from ./dataset/img/281/W/2.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: There are no visible signs or painted markers indicating designated bike lanes on the road in the image.
#
# 	Stella: I got the image from ./dataset/img/281/W/5.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: There are no visible signs or painted markers indicating designated bike lanes on the road in the image.
#
# 	Stella: I got the image from ./dataset/img/281/W/7.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: There are no visible signs or painted markers indicating designated bike lanes in the image. The road appears to be a standard street without any bike lane markings.
#
# 	Stella: I got the image from ./dataset/img/281/W/9.jpg. I'm starting annotation now...
# 	Stella: My annotation is 0
# 	Stella: There are no visible signs or painted markers indicating designated bike lanes in the image. The road appears to be a standard street without any bike lane markings.
#
#
# Streetlens: Finalizing merge of annotations and saving results to ./dataset/annotation/agent_annotation.csv.
# {'281/W': {'Disorder 3': [0,
#    [{'6.jpg': 'The image does not show any visible graffiti on buildings, signs, walls, fences, sidewalks, poles, or streets. The scene appears to be a quiet residential area with no signs of graffiti.'},
#     {'8.jpg': 'The image does not show any visible graffiti on buildings, signs, walls, fences, sidewalks, poles, or streets. The scene appears to be a quiet street with a car and some trees, but no graffiti is present. The focus is on the car and the surrounding environment, which does not include any markings or tags.'},
#     {'10.jpg': 'The image does not show any visible graffiti on buildings, signs, walls, fences, sidewalks, poles, or streets. The scene appears to be a quiet street with no signs of graffiti.'},
#     {'1.jpg': 'The image does not show any visible graffiti on buildings, signs, walls, fences, sidewalks, poles, or streets. The scene appears to be a quiet, possibly residential area with no signs of graffiti.'},
#     {'3.jpg': 'The image does not show any visible graffiti on buildings, signs, walls, fences, sidewalks, poles, or streets. The scene appears to be a quiet residential area with no signs of graffiti.'},
#     {'2.jpg': 'The image does not show any visible graffiti on buildings, signs, walls, fences, sidewalks, poles, or streets. The scene appears to be a quiet residential area with no signs of graffiti.'},
#     {'5.jpg': 'The image shows a street view with no visible graffiti on buildings, signs, walls, fences, sidewalks, poles, or streets. The area appears clean and well-maintained, with only a few bare trees and a residential house in the background. There are no markings, tags, or spray paint present in the image.'},
#     {'7.jpg': 'The image shows a gas station with no visible graffiti on buildings, signs, walls, fences, sidewalks, poles, or streets. The area appears clean and well-maintained.'},
#     {'9.jpg': 'The image shows a gas station with no visible graffiti on buildings, signs, walls, fences, sidewalks, poles, or streets. The area appears clean and well-maintained.'}]],
#   'Decay 1': [3,
#    [{'6.jpg': 'The street shows significant cracks and potholes, indicating poor condition. Most of the street has noticeable damage, with cracks and potholes that have not been recently filled in. This suggests the street is in a poor condition.'},
#     {'8.jpg': 'The street shows significant cracks and potholes, indicating poor condition. Most of the street has noticeable damage, with minimal recent filling. This suggests the street is in a poor condition.'},
#     {'10.jpg': 'The street shows significant cracks and potholes, indicating poor condition. Most of the street has noticeable damage, with cracks and potholes that have not been recently filled in. This suggests the street is in a poor condition.'},
#     {'1.jpg': 'The street in the image shows significant cracks and potholes, indicating poor condition. Most of the street appears to have substantial damage, with cracks and potholes that have not been recently filled in. This suggests that the street is in a poor condition.'},
#     {'3.jpg': 'The street in the image shows significant cracks and potholes, indicating poor condition. Most of the street appears to have substantial damage, with cracks and potholes that have not been recently filled in. This suggests that the street is in a poor condition.'},
#     {'2.jpg': 'The street shows significant cracks and potholes, indicating poor condition. Most of the street has noticeable damage, with cracks and potholes that have not been recently filled in. This suggests the street is in a poor condition.'},
#     {'5.jpg': 'The street in the image shows significant cracks and potholes, indicating poor condition. Most of the street is affected, with substantial damage that has not been recently repaired. This suggests the street is in a poor condition.'},
#     {'7.jpg': 'The street in the image shows significant cracks and potholes, indicating poor condition. Most of the street appears to be affected, with substantial damage that has not been recently repaired.'},
#     {'9.jpg': 'The street in the image shows significant cracks and potholes, indicating poor condition. Most of the street appears to have substantial damage, with cracks and potholes that have not been recently filled in. This suggests that the street is in a poor condition.'}]],
#   'Decay 2': [3,
#    [{'6.jpg': 'The sidewalk in the image shows significant signs of deterioration, including sizable cracks and outgrown weeds along most of the sidewalk. This indicates poor conditions, making it unsuitable for safe walking. The presence of these issues suggests the sidewalk is not in good condition.'},
#     {'8.jpg': 'The sidewalk in the image shows significant signs of wear and tear, with visible holes, sizable cracks, and weeds growing along most of the sidewalk. This indicates poor conditions that are likely to affect pedestrian safety and comfort.'},
#     {'10.jpg': 'The sidewalk in the image shows significant cracks and uneven pavement, with weeds growing along most of the sidewalk. This indicates poor conditions. There are no visible holes or large cracks, but the overall condition is deteriorated. The presence of weeds suggests neglect, which contributes to a poor sidewalk condition.'},
#     {'1.jpg': 'The sidewalk in the image shows significant signs of wear and tear, with visible holes, sizable cracks, and weeds growing along most of the sidewalk. This indicates poor conditions that are likely to affect pedestrian safety and comfort.'},
#     {'3.jpg': 'The sidewalk in the image shows significant signs of wear and tear, with visible holes, sizable cracks, and weeds growing along most of the sidewalk. This indicates poor conditions that are not suitable for safe walking. The presence of these issues suggests the sidewalk is in a poor condition.'},
#     {'2.jpg': ''},
#     {'5.jpg': 'The sidewalk in the image shows significant signs of wear and tear, with visible holes, sizable cracks, and weeds growing along most of the sidewalk. This indicates poor conditions that are likely to affect pedestrian safety and comfort.'},
#     {'7.jpg': 'The sidewalk in the image shows significant cracks, crumbling pavement, and outgrown weeds along most of the sidewalk, indicating poor conditions. There are no visible holes or sizable cracks, and the pavement is not uneven. The presence of weeds suggests neglect, which is characteristic of a poor sidewalk condition.'},
#     {'9.jpg': 'The sidewalk in the image shows significant signs of wear and tear, with visible holes, sizable cracks, and weeds growing along most of the sidewalk. This indicates poor maintenance and a less desirable condition compared to a good or fair sidewalk. The presence of these issues suggests the sidewalk is in a poor condition.'}]],
#   'SS4': [1,
#    [{'6.jpg': 'The image shows a pedestrian crossing sign, indicating the presence of crosswalks or signs signaling to watch for pedestrians. This is a clear indicator of pedestrian safety measures in the neighborhood.'},
#     {'8.jpg': 'The image shows a pedestrian crossing sign, indicating the presence of crosswalks or signs signaling to watch for pedestrians. This is a clear indicator of pedestrian safety measures in the neighborhood.'},
#     {'10.jpg': 'The image shows visible crosswalks and pedestrian signs, indicating a focus on safety for pedestrians. These elements are important for both researchers and adolescents in understanding neighborhood environments. The presence of these signs suggests a consideration of pedestrian safety, which is a shared aspect of their observations. However, the image does not provide specific details about the usage of ethnic-racial labels, so this aspect is not as clearly highlighted. Overall, the crosswalks and signs are a notable shared element in the image.'},
#     {'1.jpg': 'The image shows a street with a crosswalk, indicating the presence of crosswalks or pedestrian signs. However, there are no visible signs specifically signaling to watch for pedestrians. The focus is on the road and surrounding buildings, with no clear indicators of pedestrian safety features.'},
#     {'3.jpg': ''},
#     {'2.jpg': 'The image shows a street with a visible yellow double line, which typically indicates a no-passing zone, but it does not clearly show crosswalks or pedestrian signs. The road appears to be a two-way street without visible pedestrian markings or signals.'},
#     {'5.jpg': 'The image shows a street with a double yellow line, which typically indicates a no-passing zone. However, there are no visible crosswalks or pedestrian signs, making it difficult to confirm the presence of crosswalks or signs signaling to watch for pedestrians.'},
#     {'7.jpg': ''},
#     {'9.jpg': ''}]],
#   'SS5': [0,
#    [{'6.jpg': 'There are no visible signs or painted markers indicating designated bike lanes in the image. The road appears to be a standard street without any bike lane markings.'},
#     {'8.jpg': 'There are no visible signs or painted markers indicating designated bike lanes in the image. The road appears to be a standard street without any bike lane markings.'},
#     {'10.jpg': 'There are no visible signs or painted markers indicating designated bike lanes in the image. The road appears to be a standard street without any bike lane markings.'},
#     {'1.jpg': 'There are no visible signs or painted markers indicating designated bike lanes in the image. The road appears to be a standard street without any bike lane markings.'},
#     {'3.jpg': 'There are no visible signs or painted markers indicating designated bike lanes in the image. The road appears to be a standard street without any bike lane markings.'},
#     {'2.jpg': 'There are no visible signs or painted markers indicating designated bike lanes on the road in the image.'},
#     {'5.jpg': 'There are no visible signs or painted markers indicating designated bike lanes on the road in the image.'},
#     {'7.jpg': 'There are no visible signs or painted markers indicating designated bike lanes in the image. The road appears to be a standard street without any bike lane markings.'},
#     {'9.jpg': 'There are no visible signs or painted markers indicating designated bike lanes in the image. The road appears to be a standard street without any bike lane markings.'}]]}}
